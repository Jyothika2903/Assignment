# %%
#                                          Restaurant Problem
#Objective: Create python program to create Restaurant style application using Python. 
#Steps to perform
#1.Create Menu using dictionary . Dictionary of Items along with prices. 
#2.Create Tables info using Dictionary. Dictionary of Table Number with capacity
#3.Create Table occupied dictionary using table number and occupied or not. 
#4.Create Waiter info using Dictionary. Dictionary with waiterID, Table numbers waiter handles in list. 
#5.Create a function to display the Menu as good as Possible. (Organized)
#6.Create a function to assign a table based on capacity. Function should take, Number of People, Check each table capacity 
#and if table capacity>=People and not occupied assign the table and mark table as occupied. 
#Note: Table capacity should be as optimum as possible. If 2 people comes don’t assign table of 10 capacity. 
#7.Create a function to take the order, (Allow to enter any number of orders). And supply the bill with the help of
#gill generation function (look at 8). 
#8.Create a function to generate bill, which should show itemized bill and total bill along with GST, WaiterID, table number,
#time of Order, Restaurant Name on Top. 
#9.Create a function to clear the table occupancy of table, and write to file (See point 11).
#10.Create a function to ask for the feedback by creating the feedback dictionary. 
#11.Store WaiterID, TableNo, OrderAmount, Tip(if Any), GSTamount in file (Do it only after File Handling session is completed)
#12.Handle any exceptions wherever possible (Do it after Exception Handling).
#13.Re-create Entire Program using OOPS style (Once OOPS done)

#Note: Feel free to add any functions if you feel like. Any extra functionality will be added advantage.

# %%
menu_price={'soups':{'Veg Soup':60,'Mushroom Soup':65,'Tomato Soup':60,'Sweetcorn Soup':70,'Pepper Soup':60,'Chicken Soup':80},\
           'Fast Food':{'Veg Noodles':60,'Egg Noodles':70,'Chicken Noodles':80,'Veg Manchurian':65,'Chicken Manchurian':90,\
            'veg Fried Rice':65,'Egg Fried Rice':80,'Chicken Fried Rice':90},'Main Course':{'Veg Biryani':160,\
            'Veg Meals':180,'Egg Biryani':170,'Chicken Biryani':180,'Mutton Biryani':200,'Prawns Biryani':240,'Curd Rice':90},\
           'Desserts':{'Butterscotch Cake':50,'Pineapple Cake':50,'Chocolate Cake':50,'Vanilla Icecream':50,\
            'Strawberry Icecream':60,'Chocolate Icecream':60,'Butterscotch Icecream':60},'Drinks':{'Coke':60,'Sprite':60}}

table_dict={"Table-1":2,"Table-2":2,"Table-3":2,"Table-4":4,"Table-5":4,"Table-6":4,"Table-7":4,"Table-8":4,"Table-9":6,
           "Table-10":6,"Table-11":6,"Table-12":8,"Table-13":8,"Table-14":10,"Table-15":10}

table_occupied={"Table-1":"Not Occupied","Table-2":"Not Occupied","Table-3":"Not Occupied","Table-4":"Not Occupied",\
                "Table-5":"Not Occupied","Table-6":"Not Occupied","Table-7":"Not Occupied","Table-8":"Not Occupied",\
                "Table-9":"Not Occupied","Table-10":"Not Occupied","Table-11":"Not Occupied","Table-12":"Not Occupied",\
                "Table-13":"Not Occupied","Table-14":"Not Occupied","Table-15":"Not Occupied"}

waiter_dict={"Waiter-1":["Table-1","Table-4","Table-14"],"Waiter-2":["Table-2","Table-5","Table-15"],\
             "Waiter-3":["Table-3","Table-9","Table-12"],"Waiter-4":["Table-6","Table-10","Table-13"],\
             "Waiter-5":["Table-7","Table-8","Table-11"]}

# %%
def menu():
    print("*"*50,"  JYOTHIKA RESTAURANT  ","*"*50,"\n")
    print("="*124,"\n")
    print("-"*124,"\n","ITEMS"," "*71,"PRICE")
    for i in menu_price.keys():
        print("-"*124)
        print(i,":")
        print("-"*124)
        for j in menu_price[i]:
            print(j,end="")
            print(" "*(80-len(j)),end="")
            print(menu_price[i][j],"\n")
    print("="*124)
    print(" "*45,"HAVE A HAPPY MEAL :)")
    print("="*124)

# %%
def table_capacity(n):
    try:
        waiter_dict1={"Table-1":"Waiter-1","Table-2":"Waiter-2","Table-3":"Waiter-3","Table-4":"Waiter-1","Table-5":"Waiter-2",\
                "Table-6":"Waiter-4","Table-7":"Waiter-5","Table-8":"Waiter-5","Table-9":"Waiter-3","Table-10":"Waiter-4",\
                "Table-11":"Waiter-5","Table-12":"Waiter-3","Table-13":"Waiter-4","Table-14":"Waiter-1","Table-15":"Waiter-2"}
        for i in list(table_dict.keys()):
            if table_dict[i]<=(2*n) and table_dict[i]>=n:
                if table_occupied[i]=="Not Occupied":
                    table_occupied[i]="Occupied"
                    return i,waiter_dict1[i]   
    except:
        return None

# %%
def order(*args):
    try:
        global now,time
        menu_order={'Veg Soup':60,'Mushroom Soup':65,'Tomato Soup':60,'Sweetcorn Soup':70,'Pepper Soup':60,\
                'Chicken Soup':80,'Veg Noodles':60,'Egg Noodles':70,'Chicken Noodles':80,'Veg Manchurian':65,\
                'Chicken Manchurian':90,'veg Fried Rice':65,'Egg Fried Rice':80,'Chicken Fried Rice':90,\
                'Veg Biryani':160,'Veg Meals':180,'Egg Biryani':170,'Chicken Biryani':180,'Mutton Biryani':200,\
                'Prawns Biryani':240,'Curd Rice':90,'Butterscotch Cake':50,'Pineapple Cake':50,'Chocolate Cake':50,\
                'Vanilla Icecream':50,'Strawberry Icecream':60,'Chocolate Icecream':60,'Butterscotch Icecream':60,\
                'Coke':60,'Sprite':60}
        order_dict={}
        from datetime import datetime
        now=datetime.now()
        time = now.strftime("%d/%m/%Y %H:%M:%S")
        for i in args:
            order_dict[i]=menu_order[i]
        return order_dict
    except:
        return "Enter correct order"

# %%
def bill_generator(person_order,t):
    global tip
    tip=int(input("Would you like to give any tip. Please enter the amount:"))
    print("*"*50,"JYOTHIKA RESTAURANT","*"*50,"\n")
    print("="*124,"\n")
    print("Table Number:"," "*71,t[0],"\n")
    print("Waiter ID:"," "*74,t[1],"\n")
    print("Order Date and Time:"," "*64,time,"\n")
    print("-"*124)
    print("Item"," "*80,"Price")
    print("-"*124,"\n")
    for i in list(person_order.keys()):
        print(i," "*(85-len(i)),person_order[i],"\n")
    bill=0
    for i in list(person_order.keys()):
        bill=bill+person_order[i]
    print("-"*124)
    print("Amount:"," "*78,bill)
    print("-"*124)
    gstbill=bill*0.05
    print("GST Amount(5%):"," "*70,gstbill)
    print("Tip Amount:"," "*74,tip)
    print("="*124)
    gbill=bill+bill*0.05+tip
    print("Total Amount:"," "*72,gbill,"\n")
    print("="*124)
    print(" "*50,"HAVE A NICE DAY :)")
    print("="*124)
    order_info(person_order,time,t[0],t[1],bill,gstbill,tip,gbill)
    table_occupied[t[0]]="Not Occupied"

# %%
def order_info(*args):
    try:
        with open("Restaurant_info.txt","a") as ri:
            ri.write("Order Details:\n")
            for i in args:
                ri.write(str(i))
                ri.write("\n")
    except:
        print("No Order details found")

# %%
def feedback_form():
    name=input("Name:")
    email=input("Email:")
    phno=int(input("Phone Number"))
    food_quality=input("Rate Our food Quality(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
    over_all_service=input("Rate Our Overall Service(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
    Cleanliness=input("Rate Our Cleanliness/Ambience(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
    value=input("Rate Our Food prices(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
    overall_experience=input("Rate your Overall Experience in Our Restaurant(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
    suggestions=input("Any Comments/Suggestions:\n")
    print("="*124)
    print(" "*36,"THANKS FOR YOUR VALUABLE FEEDBACK :)")
    print("="*124)

# %%
menu()
# Out:
# **************************************************   JYOTHIKA RESTAURANT   **************************************************
#
# ...
#
# ----------------------------------------------------------------------------------------------------------------------------
#  ITEMS                                                                         PRICE
# ----------------------------------------------------------------------------------------------------------------------------
# soups :
# ----------------------------------------------------------------------------------------------------------------------------
# Veg Soup                                                                        60
#
# Mushroom Soup                                                                   65
#
# Tomato Soup                                                                     60
#
# Sweetcorn Soup                                                                  70
#
# ...

# %%
n=int(input("Enter number of people:"))
t1=table_capacity(n)
if t1== None:
    print("All Tables are Occupied")
else:
    print("Your are Assigned",t1[0],"and",t1[1])
# Out:
# Enter number of people:3
# Your are Assigned Table-4 and Waiter-1

# %%
order1=order("Veg Soup","Veg Manchurian","Chicken Biryani","Butterscotch Cake","Coke")
print("Your order:",order1)
# Out:
# Your order: {'Veg Soup': 60, 'Veg Manchurian': 65, 'Chicken Biryani': 180, 'Butterscotch Cake': 50, 'Coke': 60}

# %%
bill_generator(order1,t1)
# Out:
# Would you like to give any tip. Please enter the amount:30
# ************************************************** JYOTHIKA RESTAURANT **************************************************
#
# ...
#
# Table Number:                                                                         Table-4
#
# Waiter ID:                                                                            Waiter-1
#
# Order Date and Time:                                                                  23/04/2023 18:29:37
#
# ----------------------------------------------------------------------------------------------------------------------------
# Item                                                                                  Price
# ----------------------------------------------------------------------------------------------------------------------------
#
# Veg Soup                                                                               60
#
# ...

# %%
feedback_form()
# Out:
# Name:Happy
# Email:Happy@gmail.com
# Phone Number9821345645
# Rate Our food Quality(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Rate Our Overall Service(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Rate Our Cleanliness/Ambience(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 2
# Rate Our Food prices(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Rate your Overall Experience in Our Restaurant(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Any Comments/Suggestions:
# No
# ...
#                                      THANKS FOR YOUR VALUABLE FEEDBACK :)
# ...

# %%
# Using OOPS Concept

# %%
class Restaurant:
    """
    Restaurant Problem
    """
    def __init__(self):
        
        self.menu_price={'soups':{'Veg Soup':60,'Mushroom Soup':65,'Tomato Soup':60,'Sweetcorn Soup':70,'Pepper Soup':60,\
                'Chicken Soup':80},'Fast Food':{'Veg Noodles':60,'Egg Noodles':70,'Chicken Noodles':80,'Veg Manchurian':65,
                'Chicken Manchurian':90,'veg Fried Rice':65,'Egg Fried Rice':80,'Chicken Fried Rice':90},\
                'Main Course':{'Veg Biryani':160,'Veg Meals':180,'Egg Biryani':170,'Chicken Biryani':180,'Mutton Biryani':200,\
                'Prawns Biryani':240,'Curd Rice':90},'Desserts':{'Butterscotch Cake':50,'Pineapple Cake':50,\
                'Chocolate Cake':50,'Vanilla Icecream':50,'Strawberry Icecream':60,'Chocolate Icecream':60,\
                'Butterscotch Icecream':60},'Drinks':{'Coke':60,'Sprite':60}}

        self.table_dict={"Table-1":2,"Table-2":2,"Table-3":2,"Table-4":4,"Table-5":4,"Table-6":4,"Table-7":4,"Table-8":4,\
                    "Table-9":6,"Table-10":6,"Table-11":6,"Table-12":8,"Table-13":8,"Table-14":10,"Table-15":10}

        self.table_occupied={"Table-1":"Not Occupied","Table-2":"Not Occupied","Table-3":"Not Occupied",\
                            "Table-4":"Not Occupied","Table-5":"Not Occupied","Table-6":"Not Occupied",\
                            "Table-7":"Not Occupied","Table-8":"Not Occupied","Table-9":"Not Occupied",\
                            "Table-10":"Not Occupied","Table-11":"Not Occupied","Table-12":"Not Occupied",\
                            "Table-13":"Not Occupied","Table-14":"Not Occupied","Table-15":"Not Occupied"}
        
        self.waiter_dict={"Waiter-1":["Table-1","Table-4","Table-14"],"Waiter-2":["Table-2","Table-5","Table-15"],\
                     "Waiter-3":["Table-3","Table-9","Table-12"],"Waiter-4":["Table-6","Table-10","Table-13"],\
                     "Waiter-5":["Table-7","Table-8","Table-11"]}
        
    def menu(self):
        print("*"*50,"  JYOTHIKA RESTAURANT  ","*"*50,"\n")
        print("="*124,"\n")
        print("-"*124,"\n","ITEMS"," "*71,"PRICE")
        for i in menu_price.keys():
            print("-"*124)
            print(i,":")
            print("-"*124)
            for j in menu_price[i]:
                print(j,end="")
                print(" "*(80-len(j)),end="")
                print(menu_price[i][j],"\n")
        print("="*124)
        print(" "*45,"HAVE A HAPPY MEAL :)")
        print("="*124)
        
    def table_capacity(self, n):
        self.n=n
        try:
            self.waiter_dict1={"Table-1":"Waiter-1","Table-2":"Waiter-2","Table-3":"Waiter-3","Table-4":"Waiter-1",\
                         "Table-5":"Waiter-2","Table-6":"Waiter-4","Table-7":"Waiter-5","Table-8":"Waiter-5",\
                         "Table-9":"Waiter-3","Table-10":"Waiter-4","Table-11":"Waiter-5","Table-12":"Waiter-3",\
                         "Table-13":"Waiter-4","Table-14":"Waiter-1","Table-15":"Waiter-2"}
            for i in list(table_dict.keys()):
                if table_dict[i]<=(2*n) and table_dict[i]>=n:
                    if table_occupied[i]=="Not Occupied":
                        table_occupied[i]="Occupied"
                        return i,self.waiter_dict1[i]   
        except:
            return None
        
    def order(self, *args):
        self.args=args
        try:
            global now,time
            self.menu_order={'Veg Soup':60,'Mushroom Soup':65,'Tomato Soup':60,'Sweetcorn Soup':70,'Pepper Soup':60,\
                    'Chicken Soup':80,'Veg Noodles':60,'Egg Noodles':70,'Chicken Noodles':80,'Veg Manchurian':65,\
                    'Chicken Manchurian':90,'veg Fried Rice':65,'Egg Fried Rice':80,'Chicken Fried Rice':90,\
                    'Veg Biryani':160,'Veg Meals':180,'Egg Biryani':170,'Chicken Biryani':180,'Mutton Biryani':200,\
                    'Prawns Biryani':240,'Curd Rice':90,'Butterscotch Cake':50,'Pineapple Cake':50,'Chocolate Cake':50,\
                    'Vanilla Icecream':50,'Strawberry Icecream':60,'Chocolate Icecream':60,'Butterscotch Icecream':60,\
                    'Coke':60,'Sprite':60}
            self.order_dict={}
            from datetime import datetime
            now=datetime.now()
            time = now.strftime("%d/%m/%Y %H:%M:%S")
            for i in self.args:
                self.order_dict[i]=self.menu_order[i]
            return self.order_dict
        except:
            return "Enter correct order"
        
    def bill_generator(self, person_order, t):
        self.person_order=person_order
        self.t=t
        global tip
        tip=int(input("Would you like to give any tip. Please enter the amount:"))
        print("*"*50,"JYOTHIKA RESTAURANT","*"*50,"\n")
        print("="*124,"\n")
        print("Table Number:"," "*71,t[0],"\n")
        print("Waiter ID:"," "*74,t[1],"\n")
        print("Order Date and Time:"," "*64,time,"\n")
        print("-"*124)
        print("Item"," "*80,"Price")
        print("-"*124,"\n")
        for i in list((self.person_order).keys()):
            print(i," "*(85-len(i)),self.person_order[i],"\n")
        bill=0
        for i in list((self.person_order).keys()):
            bill=bill+self.person_order[i]
        print("-"*124)
        print("Amount:"," "*78,bill)
        print("-"*124)
        gstbill=bill*0.05
        print("GST Amount(5%):"," "*70,gstbill)
        print("Tip Amount:"," "*74,tip)
        print("="*124)
        gbill=bill+bill*0.05+tip
        print("Total Amount:"," "*72,gbill,"\n")
        print("="*124)
        print(" "*50,"HAVE A NICE DAY :)")
        print("="*124)
        r.order_info(person_order,time,t[0],t[1],bill,gstbill,tip,gbill)
        table_occupied[t[0]]="Not Occupied"
        
    def order_info(self, *args):
        try:
            with open("Restaurant_info.txt","a") as ri:
                ri.write("Order Details:\n")
                for i in args:
                    ri.write(str(i))
                    ri.write("\n")
        except:
            print("No Order details found")
            
    def feedback_form(self):
        name=input("Name:")
        email=input("Email:")
        phno=int(input("Phone Number"))
        food_quality=input("Rate Our food Quality(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
        over_all_service=input("Rate Our Overall Service(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
        Cleanliness=input("Rate Our Cleanliness/Ambience(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
        value=input("Rate Our Food prices(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
        overall_exper=input("Rate your Overall Experience in Our Restaurant(1. Excellent 2.Good 3.Average 4.Dissatisfied):\n")
        suggestions=input("Any Comments/Suggestions:\n")
        print("="*124)
        print(" "*36,"THANKS FOR YOUR VALUABLE FEEDBACK :)")
        print("="*124)

# %%
r=Restaurant()

# %%
r.menu()
# Out:
# **************************************************   JYOTHIKA RESTAURANT   **************************************************
#
# ...
#
# ----------------------------------------------------------------------------------------------------------------------------
#  ITEMS                                                                         PRICE
# ----------------------------------------------------------------------------------------------------------------------------
# soups :
# ----------------------------------------------------------------------------------------------------------------------------
# Veg Soup                                                                        60
#
# Mushroom Soup                                                                   65
#
# Tomato Soup                                                                     60
#
# Sweetcorn Soup                                                                  70
#
# ...

# %%
n=int(input("Enter number of people:"))
r1=r.table_capacity(n)
if r1== None:
    print("All Tables are Occupied")
else:
    print("Your are Assigned",r1[0],"and",r1[1])
# Out:
# Enter number of people:5
# Your are Assigned Table-9 and Waiter-3

# %%
order1=r.order("Veg Soup","Veg Manchurian","Chicken Biryani","Butterscotch Cake","Coke")
print("Your order:",order1)
# Out:
# Your order: {'Veg Soup': 60, 'Veg Manchurian': 65, 'Chicken Biryani': 180, 'Butterscotch Cake': 50, 'Coke': 60}

# %%
r.bill_generator(order1,r1)
# Out:
# Would you like to give any tip. Please enter the amount:30
# ************************************************** JYOTHIKA RESTAURANT **************************************************
#
# ...
#
# Table Number:                                                                         Table-9
#
# Waiter ID:                                                                            Waiter-3
#
# Order Date and Time:                                                                  23/04/2023 17:19:34
#
# ----------------------------------------------------------------------------------------------------------------------------
# Item                                                                                  Price
# ----------------------------------------------------------------------------------------------------------------------------
#
# Veg Soup                                                                               60
#
# ...

# %%
r.feedback_form()
# Out:
# Name:Happy
# Email:Happy@gmail.com
# Phone Number984532182
# Rate Our food Quality(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Rate Our Overall Service(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Rate Our Cleanliness/Ambience(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Rate Our Food prices(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 2
# Rate your Overall Experience in Our Restaurant(1. Excellent 2.Good 3.Average 4.Dissatisfied):
# 1
# Any Comments/Suggestions:
# No
# ...
#                                      THANKS FOR YOUR VALUABLE FEEDBACK :)
# ...
